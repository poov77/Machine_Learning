# %%
pip install pandas

# %%
import  pandas as pd
import numpy as np

# %%
df=pd.read_csv("claimants.csv")

# %%
df

# %%
df.dtypes

# %%
df.shape

# %%
from matplotlib import pyplot as plt

# %%
# !pip install matplotlib

# %%
df.columns

# %%
plt.scatter(df['CASENUM'],df['LOSS'])
plt.xlabel("Insurance")
plt.ylabel("Loss")
plt.show()

# %%
df.isnull().sum()

# %%
df.duplicted()

# %%
df
