# %% [markdown]
# basics

# %%
1. 🟨 Data Preprocessing & Transformation ModulesThese modules are used to clean, scale, and structurally encode your features ($X$) before they are fed into an algorithm.
    Pythonfrom sklearn.preprocessing import StandardScaler      # Z-Score Normalization (Mean=0, Std=1)
from sklearn.preprocessing import MinMaxScaler      # Rescales features to a rigid [0, 1] box
from sklearn.preprocessing import OneHotEncoder      # Converts text categories into binary columns (0s and 1s)
from sklearn.preprocessing import LabelEncoder       # Converts text categories into sequential integers (0, 1, 2...)
from sklearn.compose import ColumnTransformer        # Applies different scalers/encoders to specific columns
from sklearn.pipeline import Pipeline                # Chases data transformations and models into a single unit


2. 🟦 Model Training Algorithms (The Prediction Engines)These imports represent the actual mathematical architectures used to find patterns and map predictions.
    Python# --- Regression Models (Predicting Continuous Numbers like Price, Range, Balance) ---
    
from sklearn.linear_model import LinearRegression    # Baseline straight-line regressor
from sklearn.linear_model import Ridge, Lasso        # Regularized models designed to stop overfitting
from sklearn.preprocessing import PolynomialFeatures  # Bends a straight line into a non-linear curve

# --- Classification Models (Predicting Categories like Default vs Safe, Play vs No Play) ---
from sklearn.linear_model import LogisticRegression # S-curve probability classifier for binary outcomes
from sklearn.tree import DecisionTreeClassifier     # Simple flowchart splitting data via Entropy/Gini
from sklearn.ensemble import RandomForestClassifier  # Team of independent trees voting on the final class

# --- Unsupervised Clustering Models (Grouping Unlabeled Data Points) ---
from sklearn.cluster import KMeans                   # Groups geometric data points into 'K' tight clusters


3. 🟩 Accuracy Checkers & Model Evaluation MetricsOnce a model makes predictions, you use these modules to compare its guesses against the actual truth.
    Python# --- Data Slicing ---
    
from sklearn.model_selection import train_test_split # Separates data into Training and Testing subsets

# --- Regression Accuracy Metrics ---
from sklearn.metrics import mean_absolute_error      # MAE: Tells you average error size in raw units
from sklearn.metrics import root_mean_squared_error  # RMSE: Average error size while heavily punishing blunders
from sklearn.metrics import r2_score                 # R-Squared: Overall baseline grade percentage (0% to 100%)

# --- Classification Accuracy Metrics ---
from sklearn.metrics import accuracy_score           # Percentage of overall correct assignments
from sklearn.metrics import precision_score          # Measures cost of false alarms (False Positives)
from sklearn.metrics import recall_score             # Measures cost of missed true cases (False Negatives)
from sklearn.metrics import f1_score                 # Standard average balance used for highly uneven datasets
from sklearn.metrics import confusion_matrix         # 2x2 grid showing true vs false prediction counts
from sklearn.metrics import classification_report    # Text summary printing precision/recall/f1 per class

# --- Clustering Metrics ---
from sklearn.metrics import silhouette_score         # Measures density and physical separat
# Out:
#   Cell In[3], line 1
#     1. 🟨 Data Preprocessing & Transformation ModulesThese modules are used to clean, scale, and structurally encode your features ($X$) before they are fed into an algorithm.
#        ^
# SyntaxError: invalid character '🟨' (U+1F7E8)

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\poova\Downloads\metric-type-10.csv")
df
# Out:
#                   Metric            Type               What it Measures  \
# 0               Accuracy  Classification            Overall correctness
# 1              Precision  Classification       Correctness of positives
# 2                 Recall  Classification          Coverage of positives
# 3                     F1  Classification  Balance of precision & recall
# 4                    MSE      Regression                  Squared error
# 5                    MAE      Regression                 Absolute error
# 6                     R²      Regression             Variance explained
# 7       Confusion Matrix  Classification                Error breakdown
# 8  Classification Report  Classification  Precision/Recall/F1 per class
# 9       Silhouette Score      Clustering             Cluster separation
#
#           Range                     Key Use
# 0           0–1             Simple baseline
# 1           0–1       Avoid false positives
# ...

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\poova\Downloads\category-import-6.csv")
df
# Out:
#                    Category  \
# 0                Regression
# 1            Classification
# 2                Clustering
# 3  Dimensionality Reduction
# 4             Preprocessing
# 5                Evaluation
#
#                                               Import  \
# 0                     LinearRegression, Ridge, Lasso
# 1  LogisticRegression, RandomForestClassifier, SV...
# 2                                     KMeans, DBSCAN
# 3                                          PCA, TSNE
# 4        StandardScaler, LabelEncoder, SimpleImputer
# 5       accuracy_score, mean_squared_error, r2_score
#
#                      Purpose
# 0  Predict continuous values
# 1         Predict categories
# 2       Group unlabeled data
# 3       Reduce feature space
# 4               Prepare data
# 5        Measure performance

# %% [raw]
# 📦 Core Libraries
# import pandas as pd → Data manipulation (tables, CSVs, cleaning).
#
# import numpy as np → Numerical computing (arrays, matrices, math).
#
# import matplotlib.pyplot as plt / import seaborn as sns → Visualization (plots, charts, statistical graphics).
#
# 🤖 Scikit‑Learn (Machine Learning Toolkit)
# 1. Data Preparation
# from sklearn.model_selection import train_test_split → Split dataset into train/test.
#
# from sklearn.preprocessing import StandardScaler, MinMaxScaler → Normalize/scale features.
#
# from sklearn.preprocessing import LabelEncoder, OneHotEncoder → Encode categorical variables.
#
# from sklearn.impute import SimpleImputer → Handle missing values.
#
# 2. Regression Algorithms
# from sklearn.linear_model import LinearRegression → Linear regression.
#
# from sklearn.linear_model import Ridge, Lasso → Regularized regression (reduce overfitting).
#
# from sklearn.tree import DecisionTreeRegressor → Tree‑based regression.
#
# from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor → Ensemble regression models.
#
# 3. Classification Algorithms
# from sklearn.linear_model import LogisticRegression → Logistic regression (binary/multi‑class).
#
# from sklearn.tree import DecisionTreeClassifier → Tree‑based classification.
#
# from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier → Ensemble classifiers.
#
# from sklearn.svm import SVC → Support Vector Machine classifier.
#
# from sklearn.naive_bayes import GaussianNB → Naïve Bayes classifier.
#
# from sklearn.neighbors import KNeighborsClassifier → K‑Nearest Neighbors classifier.
#
# 4. Clustering Algorithms
# from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering → Unsupervised clustering.
#
# 5. Dimensionality Reduction
# from sklearn.decomposition import PCA → Principal Component Analysis.
#
# from sklearn.manifold import TSNE → t‑SNE visualization for high‑dimensional data.
#
# 6. Model Evaluation
# from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score → Classification metrics.
#
# from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score → Regression metrics.
#
# from sklearn.metrics import confusion_matrix, classification_report → Detailed classification evaluation.
#
# from sklearn.metrics import silhouette_score → Clustering evaluation.

# %%
🟦 Classification Metrics
Used when the target variable is categorical (e.g., spam vs. not spam, disease vs. no disease).

accuracy_score

Definition: Fraction of correct predictions out of all predictions.

Range: 
0.0
 to 
1.0
.

Limitation: Can be misleading if classes are imbalanced.

precision_score

Definition: Of all predicted positives, how many are truly positive.

Formula: 
Precision
=
𝑇
𝑃
𝑇
𝑃
+
𝐹
𝑃

Use: Important when false positives are costly (e.g., predicting cancer when it’s not there).

recall_score

Definition: Of all actual positives, how many were correctly predicted.

Formula: 
Recall
=
𝑇
𝑃
𝑇
𝑃
+
𝐹
𝑁

Use: Important when false negatives are costly (e.g., missing a cancer diagnosis).

f1_score

Definition: Harmonic mean of precision and recall.

Formula: 
𝐹
1
=
2
⋅
𝑃
𝑟
𝑒
𝑐
𝑖
𝑠
𝑖
𝑜
𝑛
⋅
𝑅
𝑒
𝑐
𝑎
𝑙
𝑙
𝑃
𝑟
𝑒
𝑐
𝑖
𝑠
𝑖
𝑜
𝑛
+
𝑅
𝑒
𝑐
𝑎
𝑙
𝑙

Use: Balances precision and recall, useful when both false positives and false negatives matter.

🟩 Regression Metrics
Used when the target variable is continuous numeric (e.g., house prices, temperature).

mean_squared_error (MSE)

Definition: Average of squared differences between predicted and actual values.

Range: 
0
 to 
∞
. Lower is better.

Penalizes large errors more strongly.

mean_absolute_error (MAE)

Definition: Average of absolute differences between predicted and actual values.

Range: 
0
 to 
∞
. Lower is better.

Easier to interpret (average error in same units as target).

r2_score (Coefficient of Determination)

Definition: Proportion of variance in target explained by the model.

Range: 
−
∞
 to 
1
.

1.0
 → perfect fit

0.0
 → no better than predicting the mean

Negative → worse than a constant baseline

🟨 Detailed Classification Evaluation
confusion_matrix

Definition: Table showing counts of True Positives, False Positives, True Negatives, False Negatives.

Use: Helps visualize misclassifications.

Example (binary classification):

classification_report

Definition: Text summary of precision, recall, F1‑score, and support (number of samples per class).

Use: Quick overview of performance across all classes.

🟥 Clustering Evaluation
silhouette_score

Definition: Measures how similar an object is to its own cluster compared to other clusters.

Range: 
−
1
 to 
1
.

Close to 
1
 → well‑clustered.

Around 
0
 → overlapping clusters.

Negative → wrong clustering.

Use: Evaluate unsupervised clustering quality (e.g., KMeans).
