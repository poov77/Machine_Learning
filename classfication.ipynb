# %%
import os
print(os.getcwd())

# %%
df = pd.read_csv("insurance_classification/claimants.csv")

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\poova\Machine Learning\insurance_classification\claimants.csv")
df

# %%
df.head()

# %%
df.tail()

# %%
del df['CASENUM']

# %%
df

# %%
df.shape

# %%
df.dtypes

# %%
df.isna().sum()

# %%
df.dropna(inplace=True,ignore_index=True)
df

# %%
df.duplicated().sum()

# %%
df[df.duplicated()]

# %%
df.drop_duplicates(inplace=True,ignore_index=True)
df

# %%
x=df.iloc[:,1:]
x

# %%
y=df.iloc[:,0]
y

# %%
df.corr()

# %%
y.unique()

# %%
(y.value_counts()[0]/df.shape[0])*100

# %%
y.value_counts()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=25,shuffle=True)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape

# %%
from sklearn.linear_model import LogisticRegression

# %%
logr=LogisticRegression()#model buliding
logr.fit(x_train,y_train)#model training

# %%
y_train_pred=logr.predict(x_train)
y_train_pred

# %%
y_test_pred=logr.predict(x_test)
y_test_pred

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

# %%
#train accuacy
confusion_matrix(y_train,y_train_pred)

# %%
(317+305)/(317+151+97+305)

# %%
accuracy_score(y_train,y_train_pred)

# %%
confusion_matrix(y_test,y_test_pred)

# %%
accuracy_score(y_test,y_test_pred)

# %%
print(classification_report(y_train,y_train_pred))

# %%
print(classification_report(y_test,y_test_pred))
