# %%
import pandas as pd

# %%
d1=pd.read_csv(r"C:\Users\poova\OneDrive\Downloads\Salary_Data.csv")

# %%
d1.shape

# %%
d1.dtypes

# %%
d1.isna().sum()

# %%
d1.duplicated().sum()

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter(d1['YearsExperience'],d1['Salary'])
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
plt.show()

# %%
x=d1[['YearsExperience']]
x

# %%
y=d1[['Salary']]
y

# %%
from sklearn.linear_model import LinearRegression

# %%
slr=LinearRegression() #model training

# %%
slr.fit(x,y)

# %%
y_pred=slr.predict(x)

# %%
y_pred.round(2)

# %%
error = y-y_pred
error

# %%
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
r2_score(y,y_pred)

# %%
mean_squared_error(y,y_pred)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# Sample dataset
data = {
    'amount': [200, 5000, 150, 7000, 300],
    'location': [1, 2, 1, 3, 2],   # encoded
    'time': [10, 23, 14, 2, 18],   # hour of day
    'fraud': [0, 1, 0, 1, 0]       # labels
}
df = pd.DataFrame(data)

# Features & target
X = df[['amount', 'location', 'time']]
y = df['fraud']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Model
model = RandomForestClassifier()
model.fit(X_train, y_train)

# Predictions
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))

# %%
print("Accuracy:", (y_test, y_pred))

# %%
from sklearn.model_selection import train_test_split
import numpy as np

X = np.arange(10).reshape((5,2))  # sample features
y = np.array([0,1,0,1,0])         # labels

# Split with random_state=42
X_train1, X_test1, y_train1, y_test1 = train_test_split(X, y, test_size=0.4, random_state=45)

# Split with random_state=7
X_train2, X_test2, y_train2, y_test2 = train_test_split(X, y, test_size=0.4, random_state=7)

print("Test set with random_state=42:", X_test1)
print("Test set with random_state=7:", X_test2)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
