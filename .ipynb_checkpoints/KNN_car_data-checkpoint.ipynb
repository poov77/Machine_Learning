# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\poova\Downloads\Cars.csv");
df
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter(df['HP'],df['MPG'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
df
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
# Select all rows, but only columns 0,1,3,4,5
x=[df.iloc[:, [0, 2, 3, 4]]]
x
# Out:
# [     HP  VOL          SP         WT
#  0    49   89  104.185353  28.762059
#  1    55   92  105.461264  30.466833
#  2    55   92  105.461264  30.193597
#  3    70   92  113.461264  30.632114
#  4    53   92  104.461264  29.889149
#  ..  ...  ...         ...        ...
#  76  322   50  169.598513  16.132947
#  77  238  115  150.576579  37.923113
#  78  263   50  151.598513  15.769625
#  79  295  119  167.944460  39.423099
#  80  236  107  139.840817  34.948615
#
#  [81 rows x 4 columns]]

# %%
y=df.iloc[:,1:2]
y
# Out:
#           MPG
# 0   53.700681
# 1   50.013401
# 2   50.013401
# 3   45.696322
# 4   50.504232
# ..        ...
# 76  36.900000
# 77  19.197888
# 78  34.000000
# 79  19.833733
# 80  12.101263
#
# [81 rows x 1 columns]

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler

ss=MinMaxScaler()
x=ss.fit_transform(x)
x
# Out:
# array([[0.        , 0.35454545, 0.0659747 , 0.34998626],
#        [0.02197802, 0.38181818, 0.08419325, 0.39570917],
#        [0.02197802, 0.38181818, 0.08419325, 0.38838083],
#        [0.07692308, 0.38181818, 0.19842412, 0.40014209],
#        [0.01465201, 0.38181818, 0.06991439, 0.38021538],
#        [0.07692308, 0.35454545, 0.19448443, 0.37223949],
#        [0.02197802, 0.38181818, 0.08419325, 0.39146205],
#        [0.04761905, 0.        , 0.04331644, 0.00361807],
#        [0.04761905, 0.        , 0.04331644, 0.01734281],
#        [0.11355311, 0.4       , 0.2296083 , 0.40786748],
#        [0.08791209, 0.35454545, 0.16592671, 0.36611296],
#        [0.15750916, 0.        , 0.25749932, 0.00109096],
#        [0.15750916, 0.44545455, 0.32184761, 0.45865046],
#        [0.08791209, 0.35454545, 0.16592671, 0.36651781],
#        [0.06227106, 0.35454545, 0.12309014, 0.36568216],
#        [0.08791209, 0.35454545, 0.16592671, 0.37258167],
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,shuffle=True,random_state=12)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((64, 4), (17, 4), (64, 1), (17, 1))

# %%
from sklearn.neighbors import KNeighborsClassifier,KNeighborsRegressor

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score

# If y_train is a DataFrame with one column, convert it:
y_train = y_train.values.ravel()   # or y_train.squeeze()
y_test  = y_test.values.ravel()

# Initialize KNN for regression
knn = KNeighborsRegressor(n_neighbors=3)

# Fit on training data
knn.fit(x_train, y_train)

# Predictions
y_train_pred = knn.predict(x_train)
y_test_pred  = knn.predict(x_test)

# Evaluate
print("Train R²:", r2_score(y_train, y_train_pred))
print("Test R²:", r2_score(y_test, y_test_pred))
print("Test RMSE:", mean_squared_error(y_test, y_test_pred, squared=False))
# Out:
# Train R²: 0.9551195436127188
# Test R²: 0.7053686723920074
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 21
#      19 print("Train R²:", r2_score(y_train, y_train_pred))
#      20 print("Test R²:", r2_score(y_test, y_test_pred))
# ---> 21 print("Test RMSE:", mean_squared_error(y_test, y_test_pred, squared=False))
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:196, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
# --> 196 params = func_sig.bind(*args, **kwargs)
#     197 params.apply_defaults()
#     199 # ignore self/cls and positional/keyword markers
#
# File ~\anaconda3\Lib\inspect.py:3304, in Signature.bind(self, *args, **kwargs)
#    3299 def bind(self, /, *args, **kwargs):
# ...

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
confusion_matrix(y_train_pred,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 confusion_matrix(y_train_pred,y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
# ...

# %%
print(classification_report(y_train_pred,y_train))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 print(classification_report(y_train_pred,y_train))
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
# ...
